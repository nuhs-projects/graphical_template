# %%
from src.graphical_template.plots import NUHS_bar_chart, NUHS_stacked_bar_chart, NUHS_grouped_bar_chart

# %%
# 4. Example data
labels = ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7', 'Q8','Q9', 'Q10', 'Q11', 'Q12']
values = [15, 23, 12, 34, 22, 18, 27, 30,23,40,15,27]

# 5. Plot the chart
NUHS_bar_chart(labels, values, title = 'Gradient Bar Chart')

# %%
labels = ["Q1", "Q2", "Q3", "Q4"]
category_names = ["Product A", "Product B", "Product C", "Product D"]
data = [
    [10, 15, 20, 25],  # Product A
    [5,  10, 15, 10],  # Product B
    [2,  5,  10, 5],    # Product C
    [3,  16,  5, 9]    # Product C
]

NUHS_stacked_bar_chart(labels, data, category_names)

# %%
labels = ['Q1', 'Q2', 'Q3', 'Q4']
category_names = ['Product A', 'Product B']
data = [
    [20, 35, 30, 35],
    [25, 32, 34, 20]
]

NUHS_grouped_bar_chart(labels, data, category_names)

# %%
labels = ['Q1', 'Q2', 'Q3', 'Q4', 'Q5']
category_names = ['Product A', 'Product B', 'Product C', 'Product D', 'Product E']
data = [
    [20, 35, 30, 35, 40],
    [25, 32, 34, 20, 30],
    [15, 22, 18, 25, 28],
    [10, 20, 15, 18, 22]
]

NUHS_grouped_bar_chart(labels, data, category_names)
